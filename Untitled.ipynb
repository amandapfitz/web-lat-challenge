# %%
import pandas as pd

# %%
file_path = 'cities_summary_data.csv'

# %%
csv = pd.read_csv(file_path,',')

# %%
cities_df = pd.DataFrame(csv)

# %%
cities_df.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0     Norman Wells        75.0      CA  1.570825e+09      74.0  65.28 -126.83
# 1    Mar del Plata        16.0      AR  1.570825e+09      61.0 -46.43  -67.52
# 2            Hobyo        20.0      SO  1.570825e+09      79.0   5.35   48.53
# 3  Bambous Virieux        75.0      MU  1.570825e+09      83.0 -20.34   57.76
# 4      East London        70.0      ZA  1.570825e+09      81.0 -33.02   27.91
#
#    Max Temp  Wind Speed
# 0     35.60        5.82
# 1     47.79        5.55
# 2     80.35       11.40
# 3     71.60        8.05
# 4     65.10       10.50

# %%
cities_df_html = cities_df.to_html("cities_df_html")

# %%
print(cities_df_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Norman Wells</td>
#       <td>75.0</td>
#       <td>CA</td>
#       <td>1.570825e+09</td>
#       <td>74.0</td>
#       <td>65.28</td>
#       <td>-126.83</td>
#       <td>35.60</td>
#       <td>5.82</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mar del Plata</td>
#       <td>16.0</td>
#       <td>AR</td>
#       <td>1.570825e+09</td>
#       <td>61.0</td>
#       <td>-46.43</td>
#       <td>-67.52</td>
#       <td>47.79</td>
#       <td>5.55</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hobyo</td>
#       <td>20.0</td>
#       <td>SO</td>
# ...
